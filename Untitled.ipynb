# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import sklearn.datasets

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression

# %%
import seaborn as sn

# %%
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("Breast Cancer datasets.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0             0.12              0.28            0.30                 0.15
# 1             0.08              0.08            0.09                 0.07
# 2             0.11              0.16            0.20                 0.13
# 3             0.14              0.28            0.24                 0.11
# 4             0.10              0.13            0.20                 0.10
#
# ...

# %%
#MISSING VALUE
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (569, 32)

# %%
df1 = df.drop(columns=['id'])

# %%
df1.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127381     19.289649       91.969033   654.889104
# std       3.523928      4.301036       24.298981   351.914129
# min       6.980000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096239          0.104464        0.088840             0.048981
# std           0.014496          0.052989        0.079806             0.038975
# min           0.050000          0.020000        0.000000             0.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave_points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
y = df1["diagnosis"]
x = df1.drop(columns=["diagnosis"])

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0             0.12
# 1          20.57         17.77          132.90     1326.0             0.08
# 2          19.69         21.25          130.00     1203.0             0.11
# 3          11.42         20.38           77.58      386.1             0.14
# 4          20.29         14.34          135.10     1297.0             0.10
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0             0.11
# 565        20.13         28.25          131.20     1261.0             0.10
# 566        16.60         28.08          108.30      858.1             0.08
# 567        20.60         29.33          140.10     1265.0             0.12
# 568         7.76         24.54           47.92      181.0             0.05
#
# ...

# %%
df1['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
scaler = StandardScaler()
scaler.fit_transform(x)
# Out:
# array([[ 1.09707601, -2.07333501,  1.26993369, ...,  2.36274807,
#          2.73877027,  1.98192509],
#        [ 1.82985767, -0.35363241,  1.68595471, ...,  1.14526683,
#         -0.16651042,  0.33080448],
#        [ 1.57991664,  0.45618695,  1.56650313, ...,  1.9061926 ,
#          1.12472544,  0.33080448],
#        ...,
#        [ 0.70228279,  2.0455738 ,  0.67267578, ...,  0.38434107,
#         -1.13493732, -0.21956906],
#        [ 1.83837839,  2.33645719,  1.98252415, ...,  2.36274807,
#          1.93174785,  1.98192509],
#        [-1.80848849,  1.22179204, -1.81438851, ..., -1.74625109,
#         -0.00510594, -0.76994259]])

# %%
dft = pd.DataFrame(scaler.fit_transform(x))

# %%
#PCA
pca = PCA(n_components=20)
pca.fit_transform(dft)
# Out:
# array([[ 9.3918    ,  2.59803013, -0.52155518, ...,  0.18129094,
#         -0.13169716, -0.352852  ],
#        [ 2.31734222, -3.70895594, -0.93855512, ..., -0.42197201,
#         -0.2368821 ,  0.08042208],
#        [ 5.65333346, -1.05129224, -0.67731896, ..., -0.63402055,
#          0.14843119,  0.26362513],
#        ...,
#        [ 1.31537455, -1.73386011,  0.85146131, ...,  0.02136223,
#         -0.14954414,  0.12375359],
#        [10.53227289,  2.28837402, -1.25985993, ...,  0.89007872,
#          0.16115795, -0.10089892],
#        [-5.45268476, -0.74322221,  1.66946039, ..., -0.30963585,
#         -0.03257   , -0.48748382]])

# %%
pd.DataFrame(pca.fit_transform(x))
# Out:
#               0           1          2          3          4         5   \
# 0    1160.142571 -293.917546  48.578473  -8.712007  32.000404  1.265332
# 1    1269.122445   15.630184 -35.394506  17.861243  -4.334722 -0.225583
# 2     995.793897   39.156750  -1.709507   4.199081  -0.466495 -2.652515
# 3    -407.180794  -67.380321   8.673020 -11.760183   7.115581  1.299788
# 4     930.341181  189.340739   1.374868   8.499106   7.613445  1.021379
# ..           ...         ...        ...        ...        ...       ...
# 564  1414.126671  110.222491  40.065858   6.562307  -5.103103 -0.395760
# 565  1045.018844   77.057587   0.036540  -4.753024 -12.417861 -0.059791
# 566   314.501764   47.553529 -10.442187  -9.772221  -6.156193 -0.870390
# 567  1124.858109   34.129222 -19.742143 -23.660930   3.565055  4.086090
# 568  -771.527593  -88.643109  23.888997   2.546907 -14.717400  4.417960
#
#            6         7         8         9         10        11        12  \
# ...

# %%
variance = pca.explained_variance_ratio_

# %%
plt.bar(np.arange(len(variance)), variance, alpha=0.5, align='center')
plt.xticks(np.arange(len(variance)), ['PC{}'.format(i+1) for i in range(len(variance))])
plt.ylabel('Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Bar Plot')
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(x, y, test_size=0.2,random_state=42)

# %%
print('shape of training set: ',X_train.shape)
print('shape of test set: ',X_test.shape)
# Out:
# shape of training set:  (455, 30)
# shape of test set:  (114, 30)

# %%
scaled_df1 = scaler.transform(df1)
pd.DataFrame(scaled_df1)
# Out:
#      0         1         2         3         4         5         6         7   \
# 0   NaN  1.097076 -2.073335  1.269934  0.984375  1.640615  3.315591  2.648228
# 1   NaN  1.829858 -0.353632  1.685955  1.908708 -1.121249 -0.462085  0.014547
# 2   NaN  1.579917  0.456187  1.566503  1.558884  0.950149  1.048985  1.394094
# 3   NaN -0.768961  0.253732 -0.592687 -0.764464  3.021547  3.315591  1.895747
# 4   NaN  1.750331 -1.151816  1.776573  1.826229  0.259683  0.482334  1.394094
# ..   ..       ...       ...       ...       ...       ...       ...       ...
# 564 NaN  2.111041  0.721473  2.060786  2.343856  0.950149  0.293450  1.895747
# 565 NaN  1.704887  2.085134  1.615931  1.723842  0.259683 -0.084317  0.641614
# 566 NaN  0.702283  2.045574  0.672676  0.577953 -1.121249 -0.084317  0.014547
# 567 NaN  1.838378  2.336457  1.982524  1.735218  1.640615  3.315591  3.275294
# 568 NaN -1.808488  1.221792 -1.814389 -1.347789 -3.192646 -1.217620 -1.114173
#
# ...

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()
